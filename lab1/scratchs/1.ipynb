# %%
# %matplotlib inline
from sympy import *
from sympy.abc import x, y, z
from sympy.plotting import (plot_parametric,plot_implicit,
                            plot3d,plot3d_parametric_line,
                            plot3d_parametric_surface)
from lab1.tools import *
from lab1.grad import *

# %%
n = 2
stringFunc = "-x0^2 + x1^2 - 1000"
start_point = sp.Matrix([[randint(-10, 10) for i in range(n)]])
start_point
# Out:
# [10  2]

# %%
from sympy import symbols
from sympy.plotting import plot3d
import sympy as sp
x0, x1 = symbols('x0 x1')
plot3d(Func(n, stringFunc).f, (x0, -50, 50), (x1, -50, 50))
