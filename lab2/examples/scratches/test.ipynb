# %%
import numpy as np
import pandas as pd

pd.options.display.max_rows = 5000
import json

# %%
with open("../../data/1analize.json", "r") as f:
    dt = json.loads(f.read())
dt
# Out:
# [{'count': 10,
#   'alpha': 0.001,
#   'batch': 1,
#   'run': 1000,
#   'name': 'adagrad',
#   'res_point': -5.021841017057918,
#   'first_err': 13660.855489009724,
#   'result_err': 13270.849417987558,
#   'batch_name': 'SGD'},
#  {'count': 10,
#   'alpha': 0.001,
#   'batch': 1,
#   'run': 1000,
#   'name': 'adam',
#   'res_point': -5.2786528873201455,
#   'first_err': 13660.855489009724,
#   'result_err': 11848.937340624543,
#   'batch_name': 'SGD'},
#  {'count': 10,
#   'alpha': 0.001,
#   'batch': 1,
#   'run': 1000,
#   'name': 'momentum',
#   'res_point': None,
#   'first_err': 13660.855489009724,
#   'result_err': None,
#   'batch_name': 'SGD'},
#  {'count': 10,
#   'alpha': 0.001,
#   'batch': 1,
#   'run': 1000,
#   'name': 'rms',
#   'res_point': -5.226670961814932,
#   'first_err': 13660.855489009724,
#   'result_err': 11920.085338700464,
#   'batch_name': 'SGD'},
#  {'count': 10,
#   'alpha': 0.001,
#   'batch': 1,
#   'run': 1000,
#   'name': 'nesterov',
# ...

# %%
df = pd.DataFrame(dt)
df
# Out:
#      count  alpha  batch   run      name      res_point     first_err
# 0       10  0.001      1  1000   adagrad  -5.021841e+00  1.366086e+04  \
# 1       10  0.001      1  1000      adam  -5.278653e+00  1.366086e+04
# 2       10  0.001      1  1000  momentum            NaN  1.366086e+04
# 3       10  0.001      1  1000       rms  -5.226671e+00  1.366086e+04
# 4       10  0.001      1  1000  nesterov            NaN  1.366086e+04
# 5       10  0.001      2  1000   adagrad  -1.962805e+00  3.524233e+04
# 6       10  0.001      2  1000      adam  -1.366109e+00  3.524233e+04
# 7       10  0.001      2  1000  momentum -9.855926e+186  3.524233e+04
# 8       10  0.001      2  1000       rms  -1.412572e+00  3.524233e+04
# 9       10  0.001      2  1000  nesterov            NaN  3.524233e+04
# 10      10  0.001      3  1000   adagrad   4.000163e+00  4.351580e+05
# 11      10  0.001      3  1000      adam   3.968005e+00  4.351580e+05
# ...
